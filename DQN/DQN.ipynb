# %%
pip install gymnasium
# Out:
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.11/dist-packages (1.0.0)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (0.0.4)

# %%
from time import sleep
import numpy as np
from IPython.display import clear_output
import gymnasium as gym
from gymnasium.envs.registration import register
import torch
from torch import nn
import torch.optim as optim
import torch.nn.functional as F

# %%
#Give colab access to your google drive:
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
#Change current directory to folder with MiniPacMan
# %cd /gdrive/MyDrive/SP 25/Reinforcement Learning/DQN
# Out:
# /gdrive/MyDrive/SP 25/Reinforcement Learning/DQN

# %%
#Import MiniPacMan environment class definition
# from MiniPacManGym import MiniPacManEnv
from MiniPacManGymV2 import MiniPacManEnv

# %%
#Register MiniPacMan in your gymnasium environments
register(
    id="MiniPacMan-v0",
    entry_point=MiniPacManEnv,  # Update with your actual module path
    max_episode_steps=20          # You can also set a default here
)
# Out:
# /usr/local/lib/python3.11/dist-packages/gymnasium/envs/registration.py:642: UserWarning: WARN: Overriding environment MiniPacMan-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")

# %%
#Create a MiniPacMan gymnasium environment
env = gym.make("MiniPacMan-v0", render_mode="human", frozen_ghost=False)

# %%
class QNetwork(nn.Module):
    def __init__(self, actions):
      super(QNetwork, self).__init__()
      self.fc1 = nn.Linear(6 * 6, 128)
      self.fc2 = nn.Linear(128, 128)
      self.fc3 = nn.Linear(128, 64)
      self.fc4 = nn.Linear(64, actions)

    def forward(self, x):
      x = x.view(x.size(0), -1)
      x = F.relu(self.fc1(x))
      x = F.relu(self.fc2(x))
      x = F.relu(self.fc3(x))
      return self.fc4(x)

# %%
class ReplayBuffer:
    def __init__(self, capacity):
        self.capacity = capacity
        self.buffer = []

    def push(self, state, action, reward, next_state, done):
        if len(self.buffer) >= self.capacity:
            self.buffer.pop(0)
        self.buffer.append((state, action, reward, next_state, done))

    def sample(self, batch_size):
        indices = np.random.choice(len(self.buffer), batch_size, replace=False)
        states, actions, rewards, next_states, dones = zip(*[self.buffer[i] for i in indices])
        return torch.stack(states), actions, torch.tensor(rewards), torch.stack(next_states), torch.tensor(dones)

# %%
q_network = QNetwork(4)
target_network = QNetwork(4)
target_network.load_state_dict(q_network.state_dict())

optimizer = optim.Adam(q_network.parameters(), lr=0.001)
loss_fn = nn.MSELoss()

# %%
#set hyperparams -- play with any of these!
gamma=0.95
buffer_size=5000
batch_size=128
num_episodes=10000
C = 500

RB=ReplayBuffer(buffer_size) #initialize Replay Buffer
epsilon=1 #initialize epsilon

for e in range(num_episodes):
  new_obs,info=env.reset()
  new_obs=torch.tensor(new_obs,dtype=torch.float32).unsqueeze(0)

  done=False
  truncated=False
  steps=0

  while not done and not truncated: #Loop for one episode
    obs=new_obs

    #choose action
    t=np.random.random()
    if t>epsilon:
      with torch.no_grad():
        action=torch.argmax(q_network(obs)).item() #exploitation
    else:
      action= env.action_space.sample()

    #take a step:
    new_obs,reward, done, truncated, info=env.step(action)
    new_obs=torch.tensor(new_obs,dtype=torch.float32).unsqueeze(0)
    RB.push(obs,action,reward,new_obs,done)
    steps+=1

    if len(RB.buffer)>=batch_size:
      states, actions, rewards, next_states, dones=RB.sample(batch_size)

      #current q-value
      actions = torch.tensor(actions, dtype=torch.long)
      current_q = q_network(states).gather(1, actions.unsqueeze(1)).squeeze(1)

      #compute target q-value
      with torch.no_grad():
        max_next_q = target_network(next_states).max(1)[0]
        target_q = rewards + (1 - dones.float()) * gamma * max_next_q

      #compute loss
      loss = loss_fn(current_q, target_q)

      #Q-network update rule:
      optimizer.zero_grad()
      loss.backward()
      optimizer.step()

  #reduce episilon if its not too low:
  epsilon = max(0.01, 0.5 * (1 - e / num_episodes) + 0.5 * epsilon * 0.997)

  #update target network perodically
  if e % C == 0:
        target_network.load_state_dict(q_network.state_dict())
        print(f"episode {e}: updated target network")

  #periodic reporting:
  if e>0 and e%100==0:
    print(f'episode: {e}, steps: {steps}, epsilon: {epsilon},win: {reward==10}')
# Out:
# episode 0: updated target network
# episode: 100, steps: 2, epsilon: 0.9871379878311228,win: False
# episode: 200, steps: 2, epsilon: 0.9771678981003151,win: False
# episode: 300, steps: 1, epsilon: 0.9671978083695076,win: False
# episode: 400, steps: 1, epsilon: 0.9572277186387,win: False
# episode 500: updated target network
# episode: 500, steps: 2, epsilon: 0.9472576289078924,win: False
# episode: 600, steps: 2, epsilon: 0.937287539177085,win: False
# episode: 700, steps: 1, epsilon: 0.9273174494462774,win: False
# episode: 800, steps: 2, epsilon: 0.9173473597154698,win: False
# episode: 900, steps: 1, epsilon: 0.9073772699846623,win: False
# episode 1000: updated target network
# episode: 1000, steps: 1, epsilon: 0.8974071802538546,win: False
# episode: 1100, steps: 1, epsilon: 0.8874370905230471,win: False
# episode: 1200, steps: 3, epsilon: 0.8774670007922394,win: False
# episode: 1300, steps: 1, epsilon: 0.8674969110614319,win: False
# episode: 1400, steps: 3, epsilon: 0.8575268213306243,win: False
# episode 1500: updated target network
# episode: 1500, steps: 1, epsilon: 0.8475567315998167,win: False
# episode: 1600, steps: 1, epsilon: 0.8375866418690092,win: False
# episode: 1700, steps: 2, epsilon: 0.8276165521382016,win: False
# episode: 1800, steps: 5, epsilon: 0.817646462407394,win: False
# episode: 1900, steps: 2, epsilon: 0.8076763726765865,win: False
# episode 2000: updated target network
# episode: 2000, steps: 1, epsilon: 0.7977062829457788,win: False
# episode: 2100, steps: 1, epsilon: 0.7877361932149713,win: False
# episode: 2200, steps: 1, epsilon: 0.7777661034841636,win: False
# episode: 2300, steps: 1, epsilon: 0.7677960137533562,win: False
# episode: 2400, steps: 3, epsilon: 0.7578259240225484,win: False
# episode 2500: updated target network
# episode: 2500, steps: 1, epsilon: 0.747855834291741,win: False
# episode: 2600, steps: 1, epsilon: 0.7378857445609334,win: False
# episode: 2700, steps: 1, epsilon: 0.7279156548301258,win: False
# episode: 2800, steps: 1, epsilon: 0.7179455650993183,win: False
# episode: 2900, steps: 4, epsilon: 0.7079754753685106,win: False
# episode 3000: updated target network
# episode: 3000, steps: 3, epsilon: 0.6980053856377031,win: False
# episode: 3100, steps: 1, epsilon: 0.6880352959068954,win: False
# episode: 3200, steps: 2, epsilon: 0.6780652061760879,win: False
# episode: 3300, steps: 2, epsilon: 0.6680951164452802,win: False
# episode: 3400, steps: 1, epsilon: 0.6581250267144727,win: False
# episode 3500: updated target network
# episode: 3500, steps: 3, epsilon: 0.6481549369836652,win: False
# episode: 3600, steps: 2, epsilon: 0.6381848472528576,win: False
# episode: 3700, steps: 18, epsilon: 0.62821475752205,win: False
# episode: 3800, steps: 3, epsilon: 0.6182446677912425,win: False
# episode: 3900, steps: 1, epsilon: 0.6082745780604348,win: False
# episode 4000: updated target network
# episode: 4000, steps: 2, epsilon: 0.5983044883296273,win: False
# episode: 4100, steps: 7, epsilon: 0.5883343985988199,win: False
# episode: 4200, steps: 6, epsilon: 0.5783643088680122,win: False
# episode: 4300, steps: 1, epsilon: 0.5683942191372047,win: False
# episode: 4400, steps: 1, epsilon: 0.558424129406397,win: False
# episode 4500: updated target network
# episode: 4500, steps: 8, epsilon: 0.5484540396755895,win: False
# episode: 4600, steps: 3, epsilon: 0.5384839499447819,win: False
# episode: 4700, steps: 4, epsilon: 0.5285138602139743,win: False
# episode: 4800, steps: 6, epsilon: 0.5185437704831668,win: False
# episode: 4900, steps: 3, epsilon: 0.5085736807523591,win: False
# episode 5000: updated target network
# episode: 5000, steps: 1, epsilon: 0.4986035910215515,win: False
# episode: 5100, steps: 5, epsilon: 0.4886335012907439,win: False
# episode: 5200, steps: 2, epsilon: 0.4786634115599363,win: False
# episode: 5300, steps: 7, epsilon: 0.4686933218291287,win: False
# episode: 5400, steps: 1, epsilon: 0.45872323209832117,win: False
# episode 5500: updated target network
# episode: 5500, steps: 11, epsilon: 0.44875314236751357,win: False
# episode: 5600, steps: 2, epsilon: 0.43878305263670603,win: False
# episode: 5700, steps: 4, epsilon: 0.42881296290589854,win: False
# episode: 5800, steps: 2, epsilon: 0.41884287317509095,win: False
# episode: 5900, steps: 5, epsilon: 0.40887278344428335,win: False
# episode 6000: updated target network
# episode: 6000, steps: 1, epsilon: 0.39890269371347575,win: False
# episode: 6100, steps: 1, epsilon: 0.38893260398266816,win: False
# episode: 6200, steps: 3, epsilon: 0.37896251425186056,win: False
# episode: 6300, steps: 3, epsilon: 0.36899242452105296,win: False
# episode: 6400, steps: 9, epsilon: 0.35902233479024537,win: False
# episode 6500: updated target network
# episode: 6500, steps: 5, epsilon: 0.3490522450594378,win: False
# episode: 6600, steps: 8, epsilon: 0.33908215532863023,win: False
# episode: 6700, steps: 1, epsilon: 0.3291120655978227,win: False
# episode: 6800, steps: 8, epsilon: 0.3191419758670151,win: False
# episode: 6900, steps: 1, epsilon: 0.3091718861362076,win: False
# episode 7000: updated target network
# episode: 7000, steps: 5, epsilon: 0.2992017964054,win: False
# episode: 7100, steps: 1, epsilon: 0.2892317066745924,win: False
# episode: 7200, steps: 4, epsilon: 0.2792616169437848,win: False
# episode: 7300, steps: 15, epsilon: 0.2692915272129772,win: False
# episode: 7400, steps: 6, epsilon: 0.2593214374821696,win: False
# episode 7500: updated target network
# episode: 7500, steps: 14, epsilon: 0.24935134775136206,win: False
# episode: 7600, steps: 3, epsilon: 0.23938125802055446,win: False
# episode: 7700, steps: 1, epsilon: 0.2294111682897469,win: False
# episode: 7800, steps: 1, epsilon: 0.2194410785589393,win: False
# episode: 7900, steps: 10, epsilon: 0.20947098882813175,win: False
# episode 8000: updated target network
# episode: 8000, steps: 10, epsilon: 0.19950089909732416,win: False
# episode: 8100, steps: 13, epsilon: 0.1895308093665166,win: False
# episode: 8200, steps: 14, epsilon: 0.17956071963570908,win: False
# episode: 8300, steps: 12, epsilon: 0.16959062990490148,win: False
# episode: 8400, steps: 11, epsilon: 0.15962054017409388,win: False
# episode 8500: updated target network
# episode: 8500, steps: 15, epsilon: 0.14965045044328631,win: False
# episode: 8600, steps: 1, epsilon: 0.13968036071247872,win: False
# episode: 8700, steps: 1, epsilon: 0.12971027098167115,win: False
# episode: 8800, steps: 12, epsilon: 0.11974018125086355,win: False
# episode: 8900, steps: 8, epsilon: 0.10977009152005596,win: False
# episode 9000: updated target network
# episode: 9000, steps: 10, epsilon: 0.09980000178924839,win: False
# episode: 9100, steps: 14, epsilon: 0.08982991205844079,win: False
# episode: 9200, steps: 18, epsilon: 0.07985982232763322,win: False
# episode: 9300, steps: 11, epsilon: 0.06988973259682565,win: False
# episode: 9400, steps: 10, epsilon: 0.05991964286601814,win: False
# episode 9500: updated target network
# episode: 9500, steps: 12, epsilon: 0.04994955313521055,win: False
# episode: 9600, steps: 4, epsilon: 0.03997946340440296,win: False
# episode: 9700, steps: 12, epsilon: 0.03000937367359538,win: False
# episode: 9800, steps: 11, epsilon: 0.020039283942787797,win: False
# episode: 9900, steps: 11, epsilon: 0.010069194211980211,win: False

# %%
obs, info = env.reset()
done = False
truncated = False

while not done and not truncated:
    env.render()
    obs=torch.tensor(obs,dtype=torch.float32).unsqueeze(0)
    with torch.no_grad():
        action = torch.argmax(q_network(obs)).item()
    obs, reward, done, truncated, info = env.step(action)
    sleep(1)
    clear_output(wait=True)

env.render()
env.close()
# Out:
# xxxxxx
# x····x
# x····x
# x····x
# x·ᗧ··x
# xxxxxx
